# %%
using Pkg
Pkg.add("ScikitLearn")
using ScikitLearn
Pkg.add("HTTP")
using HTTP
Pkg.add("DelimitedFiles")
using DelimitedFiles
Pkg.add("DataFrames")
using DataFrames

# %% [markdown]
# # Car Evaluation Dataset
# https://archive.ics.uci.edu/ml/datasets/Car+Evaluation

# %%
res = HTTP.get("https://archive.ics.uci.edu/ml/machine-learning-databases/car/car.data");

data = readdlm(res.body, ',') |> DataFrame;
rename!(data, ["buying", "maint", "doors", "persons", "lug_boot", "safety", "label"])
println(mycsv)

# %% [markdown]
# ## Naive Bayesian classifier

# %% [markdown]
# ## Some version of classification trees

# %% [markdown]
# ## Support Vector Machines

# %% [markdown]
# ## Neural Networks

# %% [markdown]
# # Abalone Dataset
# https://archive.ics.uci.edu/ml/datasets/Abalone

# %% [markdown]
# ## Naive Bayesian classifier

# %% [markdown]
# ## Some version of classification trees

# %% [markdown]
# ## Support Vector Machines

# %% [markdown]
# ## Neural Networks

# %% [markdown]
# # Madelon Dataset
# https://archive.ics.uci.edu/ml/datasets/Madelon

# %% [markdown]
# ## Naive Bayesian classifier

# %% [markdown]
# ## Some version of classification trees

# %% [markdown]
# ## Support Vector Machines

# %% [markdown]
# ## Neural Networks

# %% [markdown]
# # KDD Cup 1999 Dataset
# https://archive.ics.uci.edu/ml/datasets/KDD+Cup+1999+Data

# %% [markdown]
# ## Naive Bayesian classifier

# %% [markdown]
# ## Some version of classification trees

# %% [markdown]
# ## Support Vector Machines

# %% [markdown]
# ## Neural Networks
